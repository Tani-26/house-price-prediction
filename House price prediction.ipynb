# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
df=pd.read_csv("/content/housing.csv")

# %%
df
# Out:
#      beds  baths  size size_units  lot_size lot_size_units  zip_code    price
# 0       3    3.0  2850       sqft   4200.00           sqft     98119  1175000
# 1       4    5.0  3040       sqft   5002.00           sqft     98106  1057500
# 2       3    1.0  1290       sqft   6048.00           sqft     98125   799000
# 3       3    2.0  2360       sqft      0.28           acre     98188   565000
# 4       3    3.5  1942       sqft   1603.00           sqft     98107  1187000
# ..    ...    ...   ...        ...       ...            ...       ...      ...
# 500     5    4.5  5580       sqft      0.30           acre     98146  3800000
# 501     3    2.5  1390       sqft   1570.00           sqft     98126   575000
# 502     3    2.5  2950       sqft      0.47           acre     98118  3105000
# 503     5    5.0  3010       sqft   4887.00           sqft     98115  1807000
# 504     3    2.0  1301       sqft   3000.00           sqft     98103   895000
#
# [505 rows x 8 columns]

# %%
df.dropna(inplace=True)

# %%
df.head(10)
# Out:
#     beds  baths  size size_units  lot_size lot_size_units  zip_code    price
# 0      3    3.0  2850       sqft   4200.00           sqft     98119  1175000
# 1      4    5.0  3040       sqft   5002.00           sqft     98106  1057500
# 2      3    1.0  1290       sqft   6048.00           sqft     98125   799000
# 3      3    2.0  2360       sqft      0.28           acre     98188   565000
# 4      3    3.5  1942       sqft   1603.00           sqft     98107  1187000
# 5      2    2.0   963       sqft   4753.00           sqft     98122   701000
# 7      4    6.0  3300       sqft   5810.00           sqft     98199  1795000
# 8      4    2.0  2060       sqft   4206.00           sqft     98144  1025000
# 10     3    2.5  1760       sqft   3630.00           sqft     98122  1135000
# 12     3    2.0  2500       sqft   5000.00           sqft     98136   648000

# %%
x=df['baths']
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=False)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(np.array(x_train).reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test.values.reshape(-1, 1), y_test)
# Out:
# 0.2964375227646193
